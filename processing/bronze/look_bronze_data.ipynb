# %%
from core.spark_session import create_spark_session

DATE_PATH = "2026/02/04"

spark = create_spark_session()

df = (
    spark.read
    .option("multiLine", True)
    .json(f"s3a://data-lake/bronze/adzuna/{DATE_PATH}/*.json")
)

df.show(5)
# Out:
# +--------------------+--------------------+------------+--------------------+------+
# |            batch_id|         ingested_at|record_count|             records|source|
# +--------------------+--------------------+------------+--------------------+------+
# |4e8e87b3-08a2-4f6...|2026-02-04T07:41:...|         100|[{Adzuna::API::Re...|adzuna|
# |18b0f14f-f1de-4cf...|2026-02-04T07:41:...|         100|[{Adzuna::API::Re...|adzuna|
# |6512566d-4ff3-45b...|2026-02-04T07:41:...|          50|[{Adzuna::API::Re...|adzuna|
# +--------------------+--------------------+------------+--------------------+------+

# %%
from pyspark.sql.functions import explode, col

jobs_df = (
    df
    .filter(col("records").isNotNull())
    .select(explode("records").alias("job"))
)
jobs_df.printSchema()
# Out:
# root
#  |-- job: struct (nullable = true)
#  |    |-- __CLASS__: string (nullable = true)
#  |    |-- adref: string (nullable = true)
#  |    |-- category: struct (nullable = true)
#  |    |    |-- __CLASS__: string (nullable = true)
#  |    |    |-- label: string (nullable = true)
#  |    |    |-- tag: string (nullable = true)
#  |    |-- company: struct (nullable = true)
#  |    |    |-- __CLASS__: string (nullable = true)
#  |    |    |-- display_name: string (nullable = true)
#  |    |-- contract_time: string (nullable = true)
#  |    |-- contract_type: string (nullable = true)
#  |    |-- created: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- latitude: double (nullable = true)
#  |    |-- location: struct (nullable = true)
#  |    |    |-- __CLASS__: string (nullable = true)
#  |    |    |-- area: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- display_name: string (nullable = true)
#  |    |-- longitude: double (nullable = true)
#  |    |-- redirect_url: string (nullable = true)
#  |    |-- salary_is_predicted: string (nullable = true)
#  |    |-- salary_max: double (nullable = true)
#  |    |-- salary_min: double (nullable = true)
#  |    |-- title: string (nullable = true)

# %%
jobs_df.show(10, truncate=False)
# Out:
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |job                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{Adzuna::API::Response::Job, eyJhbGciOiJIUzI1NiJ9.eyJzIjoid0NZWDg1d0I4Ukd0R2J2by1tMWs1ZyIsImkiOiI1NTg1NDgyNTgzIn0.CMrRPpf1i4bP4UK9Zqh3AmxmZVKg5cuHeOzmCcvswNQ, {Adzuna::API::Response::Category, Teaching Jobs, teaching-jobs}, {Adzuna::API::Response::Company, Targeted Provision Ltd}, part_time, contract, 2026-01-15T02:27:50Z, You can make a difference, be rewarded, and join our impact-driven community now - at Targeted Provision we change lives ! Multiple positions are available, hiring is ongoing, and interviews are being arranged as applications come in. We will contact you with nearby tutoring work within 45 minutes drive of the advertised location and/or within 45 minutes of the postcode you provide us. What makes this role right for you: We are working with Schools and Local Authorities in your area and are loo…, 5585482583, 52.832231, {Adzuna::API::Response::Location, [UK, West Midlands, Staffordshire, Burton-On-Trent, Rolleston-On-Dove], Rolleston-On-Dove, Burton-On-Trent}, -1.648153, https://www.adzuna.co.uk/jobs/land/ad/5585482583?se=wCYX85wB8RGtGbvo-m1k5g&utm_medium=api&utm_source=9655bc34&v=B7DB266A4326F8D7FA0179454BB42C0AA990DA46, 0, 72800.0, 58240.0, SEN / SEND Tutor, Staffordshire}|
# |{Adzuna::API::Response::Job, eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTU0Njk4NzQyMiIsInMiOiJ3Q1lYODV3QjhSR3RHYnZvLW0xazVnIn0.XQlJiNJbKVXLI9ylS6JupGEBf05C5lF6YeBxWOm0JsE, {Adzuna::API::Response::Category, Engineering Jobs, engineering-jobs}, {Adzuna::API::Response::Company, RAC}, full_time, NULL, 2025-12-18T11:32:11Z, Join the RAC. Together, we’re going places. A competitive base salary of £38,625, with on-target earnings of up to £50,000 A guaranteed overtime option to increase your base salary to £44,385, plus additional overtime and bonus opportunities 40 hours per week, with core hours from 8:30am to 5pm, and 1 in 4 Saturdays. As an RAC Mobile Mechanic in the Service, Maintenance and Repair division, you’ll bring expert vehicle maintenance and diagnostic skills directly to our customers, wherever they ar…, 5546987422, 54.807781, {Adzuna::API::Response::Location, [UK, North West England, Cumbria, Wigton, Blencogo], Blencogo, Wigton}, -3.238132, https://www.adzuna.co.uk/jobs/land/ad/5546987422?se=wCYX85wB8RGtGbvo-m1k5g&utm_medium=api&utm_source=9655bc34&v=48026A32E5EA99830C768113E1B425E87E9AA9C9, 0, 50000.0, 0.0, Mobile Vehicle Technician - Carlisle}                                                     |
# |{Adzuna::API::Response::Job, eyJhbGciOiJIUzI1NiJ9.eyJzIjoid0NZWDg1d0I4Ukd0R2J2by1tMWs1ZyIsImkiOiI1NTQ2OTg3NDI1In0.yHDBwKU-tFJaTg4W8b9Qnk8xLlzyQjeXiraiiRra-AE, {Adzuna::API::Response::Category, Engineering Jobs, engineering-jobs}, {Adzuna::API::Response::Company, RAC}, full_time, NULL, 2025-12-18T11:32:11Z, Join the RAC. Together, we’re going places. A competitive base salary of £38,625, with on-target earnings of up to £50,000 A guaranteed overtime option to increase your base salary to £44,385, plus additional overtime and bonus opportunities 40 hours per week, with core hours from 8:30am to 5pm, and 1 in 4 Saturdays. As an RAC Mobile Mechanic in the Service, Maintenance and Repair division, you’ll bring expert vehicle maintenance and diagnostic skills directly to our customers, wherever they ar…, 5546987425, 54.807781, {Adzuna::API::Response::Location, [UK, North West England, Cumbria, Wigton, Blencogo], Blencogo, Wigton}, -3.238132, https://www.adzuna.co.uk/jobs/land/ad/5546987425?se=wCYX85wB8RGtGbvo-m1k5g&utm_medium=api&utm_source=9655bc34&v=E2222633E8B8B127EAFC4517CB873F9689715468, 0, 50000.0, 0.0, Mobile Mechanic}                                                                          |
# |{Adzuna::API::Response::Job, eyJhbGciOiJIUzI1NiJ9.eyJzIjoid0NZWDg1d0I4Ukd0R2J2by1tMWs1ZyIsImkiOiI1NTk1MDMzNzg3In0.Ikncrc2LK7lD7tptg-ycD7EKqduizKL1m1ZjsWbfd9k, {Adzuna::API::Response::Category, Engineering Jobs, engineering-jobs}, {Adzuna::API::Response::Company, RAC}, full_time, NULL, 2026-01-22T03:08:08Z, Join the RAC. Together, we’re going places. A competitive base salary of £38,625, with on-target earnings of up to £50,000 A guaranteed overtime option to increase your base salary to £44,385, plus additional overtime and bonus opportunities 40 hours per week, with core hours from 8:30am to 5:00pm, and 1 in 4 Saturdays As an RAC Mobile Mechanic in the Service, Maintenance and Repair division, you’ll bring expert vehicle maintenance and diagnostic skills directly to our customers, wherever they …, 5595033787, 52.032628, {Adzuna::API::Response::Location, [UK, South East England, Buckinghamshire, Milton Keynes, Crownhill], Crownhill, Milton Keynes}, -0.802219, https://www.adzuna.co.uk/jobs/land/ad/5595033787?se=wCYX85wB8RGtGbvo-m1k5g&utm_medium=api&utm_source=9655bc34&v=569CA1514F4672B2C3427E7AE9AF33E2A7227104, 0, 50000.0, 0.0, Mobile Vehicle Technician - Oxford}                               |
# |{Adzuna::API::Response::Job, eyJhbGciOiJIUzI1NiJ9.eyJzIjoid0NZWDg1d0I4Ukd0R2J2by1tMWs1ZyIsImkiOiI1NDM5NzIzODc3In0.BVoEsviojT1qcydj4YDV54LS3AmHHogRk_lEqHM1iuM, {Adzuna::API::Response::Category, Logistics & Warehouse Jobs, logistics-warehouse-jobs}, {Adzuna::API::Response::Company, Ocado Logistics}, full_time, permanent, 2025-10-09T19:06:00Z, Love being on the move and interacting with people from all walks of life? Proud to deliver quality goods on time and put a smile on thousands of faces every week? Join Ocado Logistics where there are bags of possibilities. It's our mission to provide an outstanding customer experience. Whilst others might call you delivery drivers, here at Ocado Logistics our Customer Service Team Members play a vital role, delivering top quality products on time and in an efficient manner. You’ll be out on th…, 5439723877, 53.552908, {Adzuna::API::Response::Location, [UK, North West England, Greater Manchester, Wigan, Swinley], Swinley, Wigan}, -2.628564, https://www.adzuna.co.uk/jobs/land/ad/5439723877?se=wCYX85wB8RGtGbvo-m1k5g&utm_medium=api&utm_source=9655bc34&v=1A0E924331668C825E04AFBE1DB1EF1CF3A26447, 0, 12.0, 12.0, Delivery Driver - Knowsley}                       |
# |{Adzuna::API::Response::Job, eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTYwODEyMTA3MSIsInMiOiJ3Q1lYODV3QjhSR3RHYnZvLW0xazVnIn0.1ZkmCUwBdjStXtqkAN6Kug-OyxshPucSERrsGq8nh7s, {Adzuna::API::Response::Category, Hospitality & Catering Jobs, hospitality-catering-jobs}, {Adzuna::API::Response::Company, Butlin's}, NULL, NULL, 2026-02-01T03:19:57Z, Description About the Roles We’re on the lookout for a Chefs to join us in one of the UK’s most unique Papa John’s venues—one of only two restaurant-style Papa John’s locations in the country offering a full dine-in and buffet experience. This isn’t your typical takeaway—it’s a vibrant kitchen where you’ll help deliver pizza perfection moments as part of the holiday magic. You’ll be guaranteed 35 hours per week, working to a rota of 5 days out of 7 which will include weekends. Our shifts requir…, 5608121071, 53.02692, {Adzuna::API::Response::Location, [UK, East Midlands, Nottinghamshire, Nottingham, Bestwood Village], Bestwood Village, Nottingham}, -1.186201, https://www.adzuna.co.uk/jobs/land/ad/5608121071?se=wCYX85wB8RGtGbvo-m1k5g&utm_medium=api&utm_source=9655bc34&v=8F57374C083B7542EA0B98BFEB4E40683FA12678, 0, 28600.0, 28600.0, Papa Johns Chef}                        |
# |{Adzuna::API::Response::Job, eyJhbGciOiJIUzI1NiJ9.eyJzIjoid0NZWDg1d0I4Ukd0R2J2by1tMWs1ZyIsImkiOiI1NTc0NjU4NjMwIn0.Ly8Wiuitkmrrv9wb-HX95wYkQeSxV2sq6Vom47G50bI, {Adzuna::API::Response::Category, Engineering Jobs, engineering-jobs}, {Adzuna::API::Response::Company, RAC}, full_time, NULL, 2026-01-08T21:01:25Z, At RAC, we appreciate the dedication of our colleagues who go the extra mile for our customers. In return, we offer a competitive base salary of £35,000, complimented by an average OTE ranging from £43,000 to £53,000. In addition to this, you'll also enjoy all of these extra benefits: Colleague Share Scheme – a unique opportunity to become a co-owner of our business and share in the future success of RAC Holiday allowance of 23 days & bank holidays rising to 25 with service No additional travel…, 5574658630, 52.667724, {Adzuna::API::Response::Location, [UK, West Midlands, Staffordshire, Burntwood, Chasetown], Chasetown, Burntwood}, -1.946626, https://www.adzuna.co.uk/jobs/land/ad/5574658630?se=wCYX85wB8RGtGbvo-m1k5g&utm_medium=api&utm_source=9655bc34&v=FBAC133810B21D7E176DBA5C4F7D9ABBFC3D4467, 0, 53000.0, 43000.0, Roadside Technician}                                                         |
# |{Adzuna::API::Response::Job, eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTU4MjI3MjgwOCIsInMiOiJ3Q1lYODV3QjhSR3RHYnZvLW0xazVnIn0.arv5cZfTS2VSgRyvAeR3rq5pwRelVbtjXhFOsQ8NLuA, {Adzuna::API::Response::Category, Engineering Jobs, engineering-jobs}, {Adzuna::API::Response::Company, RAC}, full_time, NULL, 2026-01-13T14:06:05Z, Join the RAC. Together, we’re going places. A competitive base salary of £38,625, with on-target earnings of up to £50,000 A guaranteed overtime option to increase your base salary to £44,385, plus additional overtime and bonus opportunities 40 hours per week, with core hours from 8:30am to 5pm, and 1 in 4 Saturdays. As an RAC Mobile Mechanic in the Service, Maintenance and Repair division, you’ll bring expert vehicle maintenance and diagnostic skills directly to our customers, wherever they ar…, 5582272808, 52.640771, {Adzuna::API::Response::Location, [UK, Eastern England, Norfolk, Norwich, West Pottergate], West Pottergate, Norwich}, 1.259946, https://www.adzuna.co.uk/jobs/land/ad/5582272808?se=wCYX85wB8RGtGbvo-m1k5g&utm_medium=api&utm_source=9655bc34&v=0C57BD6A40608EE467FC1B16A0CE3F0CA92C8B03, 0, 50000.0, 0.0, Mobile Vehicle Technician - Stevenage}                                        |
# |{Adzuna::API::Response::Job, eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTYwNDc0NjAwOSIsInMiOiJ3Q1lYODV3QjhSR3RHYnZvLW0xazVnIn0.9XtiR1xmiBwTZgrJPcE5SGRvPXdUcsDi-N363LjDkcc, {Adzuna::API::Response::Category, Engineering Jobs, engineering-jobs}, {Adzuna::API::Response::Company, Mars Petcare UK}, NULL, NULL, 2026-01-29T15:19:32Z, Job Description: Technical Manager is accountable for wholistic factory assets management to ensure all machine & equipment are in good condition & reliability to serve business priorities & purposes. This role is also managing technical team’s associates to have appropriate knowledge , skills & capability to effectively perform all asset management activities together with strong awareness & mindset adhere to all Safety and Quality policies in the factory with solid succession pipeline for fut…, 5604746009, 51.087995, {Adzuna::API::Response::Location, [UK, South West England, Somerset, Castle Cary, Ansford], Ansford, Castle Cary}, -2.514123, https://www.adzuna.co.uk/jobs/land/ad/5604746009?se=wCYX85wB8RGtGbvo-m1k5g&utm_medium=api&utm_source=9655bc34&v=8510792A598CEDCD3D84AA6D6DE51AB5DF95BA15, 1, 44934.84, 44934.84, Site Technical Manager – MARS Petcare – Castle Cary}                |
# |{Adzuna::API::Response::Job, eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTYwODEyMTI3MCIsInMiOiJ3Q1lYODV3QjhSR3RHYnZvLW0xazVnIn0.G62sEQv33JrJfD0cWtvFn-Sw3sAjsrp2pqH8Jy9N28E, {Adzuna::API::Response::Category, Teaching Jobs, teaching-jobs}, {Adzuna::API::Response::Company, Busy Bees}, full_time, NULL, 2026-02-01T03:20:08Z, Role Overview: Join Our Team at Busy Bees – Leading Nursery Group in the UK As an Early Years Educator, you will play a leading role in fostering the intellectual, social, and emotional development of children at Busy Bees. Join a company that values high-quality education and provides ample growth opportunities. About Us Busy Bees is the UK's leading nursery group, with nearly 400 nurseries across the UK and more overseas. We are dedicated to giving every child the best start in life and are p…, 5608121270, 51.382518, {Adzuna::API::Response::Location, [UK, South East England, West Berkshire, Newbury, Newtown], Newtown, Newbury}, -1.323041, https://www.adzuna.co.uk/jobs/land/ad/5608121270?se=wCYX85wB8RGtGbvo-m1k5g&utm_medium=api&utm_source=9655bc34&v=507C22B26BE8C8AB82EF109B87404C3802A1894F, 0, 28641.0, 28641.0, Nursery Practitioner Level 3}                                                  |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %%
jobs_df.select(
      "job.title",
      "job.company.display_name",
      "job.location.display_name",
      "job.salary_min",
      "job.salary_max",
      "job.contract_type"
  ) \
  .show(10, truncate=False)
# Out:
# +---------------------------------------------------+----------------------+----------------------------------+----------+----------+-------------+
# |title                                              |display_name          |display_name                      |salary_min|salary_max|contract_type|
# +---------------------------------------------------+----------------------+----------------------------------+----------+----------+-------------+
# |SEN / SEND Tutor, Staffordshire                    |Targeted Provision Ltd|Rolleston-On-Dove, Burton-On-Trent|58240.0   |72800.0   |contract     |
# |Mobile Vehicle Technician - Carlisle               |RAC                   |Blencogo, Wigton                  |0.0       |50000.0   |NULL         |
# |Mobile Mechanic                                    |RAC                   |Blencogo, Wigton                  |0.0       |50000.0   |NULL         |
# |Mobile Vehicle Technician - Oxford                 |RAC                   |Crownhill, Milton Keynes          |0.0       |50000.0   |NULL         |
# |Delivery Driver - Knowsley                         |Ocado Logistics       |Swinley, Wigan                    |12.0      |12.0      |permanent    |
# |Papa Johns Chef                                    |Butlin's              |Bestwood Village, Nottingham      |28600.0   |28600.0   |NULL         |
# |Roadside Technician                                |RAC                   |Chasetown, Burntwood              |43000.0   |53000.0   |NULL         |
# |Mobile Vehicle Technician - Stevenage              |RAC                   |West Pottergate, Norwich          |0.0       |50000.0   |NULL         |
# |Site Technical Manager – MARS Petcare – Castle Cary|Mars Petcare UK       |Ansford, Castle Cary              |44934.84  |44934.84  |NULL         |
# |Nursery Practitioner Level 3                       |Busy Bees             |Newtown, Newbury                  |28641.0   |28641.0   |NULL         |
# +---------------------------------------------------+----------------------+----------------------------------+----------+----------+-------------+
# only showing top 10 rows

# %%
from pyspark.sql.functions import col, count, when

check_null_job_df = (
    df
    .select(explode("records").alias("job"))
    .select("job.*")
)

null_stats = check_null_job_df.select([
    count(when(col(c).isNull(), c)).alias(c)
    for c in check_null_job_df.columns
])

null_stats.show(truncate=False)
# Out:
# +---------+-----+--------+-------+-------------+-------------+-------+-----------+---+--------+--------+---------+------------+-------------------+----------+----------+-----+
# |__CLASS__|adref|category|company|contract_time|contract_type|created|description|id |latitude|location|longitude|redirect_url|salary_is_predicted|salary_max|salary_min|title|
# +---------+-----+--------+-------+-------------+-------------+-------+-----------+---+--------+--------+---------+------------+-------------------+----------+----------+-----+
# |0        |0    |0       |0      |86           |191          |0      |0          |0  |10      |0       |10       |0           |0                  |0         |0         |0    |
# +---------+-----+--------+-------+-------------+-------------+-------+-----------+---+--------+--------+---------+------------+-------------------+----------+----------+-----+
